# %%
import pandas as pd
import  numpy as np

# %%
df = pd.read_csv(r'C:\Users\Dell\Desktop\Files\Data Science\Assignments\Case study on Regression\car_age_price.csv')
df.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %%
df.isnull().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
df.shape
# Out:
# (112, 2)

# %%
df.columns
# Out:
# Index(['Year', 'Price'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
year = df['Year'].values
price = df['Price'].values

# %%
plt.figure(figsize=(8, 6))
plt.scatter(year, price, color='blue', alpha=0.7)
plt.title('Hyundai Grand i10: Price vs Year')
plt.xlabel('Year')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ### simple linear regression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
x1 = df['Year']
y1 = df['Price']

# %%
x1.shape,y1.shape
# Out:
# ((112,), (112,))

# %%
x1 = np.array(x1)
y1 = np.array(y1)

# %%
x1.shape,y1.shape
# Out:
# ((112,), (112,))

# %%
x1 = x1.reshape(-1,1)
y1 = y1.reshape(-1,1)

# %%
x1.shape,y1.shape
# Out:
# ((112, 1), (112, 1))

# %%
scalar = StandardScaler()

# %%
x1 = scalar.fit_transform(x1)
y1 = scalar.fit_transform(y1)

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.3, random_state =42)

# %%
x1_train.shape, x1_test.shape, y1_train.shape, y1_test.shape
# Out:
# ((78, 1), (34, 1), (78, 1), (34, 1))

# %%
slr_model = LinearRegression()
slr_model.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
accracy_slr=slr_model.score(x1_test,y1_test)
accracy_slr
# Out:
# 0.4887760028600361

# %% [markdown]
# ### Train & Evaluate decision tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dr_model = DecisionTreeRegressor()

# %%
dr_model.fit(x1_train,y1_train)
# Out:
# DecisionTreeRegressor()

# %%
accracy_dr=dr_model.score(x1_test,y1_test)
accracy_dr
# Out:
# 0.6020198072520646

# %% [markdown]
# ### random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators= 100, max_depth=42)

# %%
rf_model.fit(x1_train,y1_train)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=42)

# %%
accuracy_rf = rf_model.score(x1_test, y_test)
accuracy_rf
# Out:
# 0.6181357430936103

# %%
predicted_price_2022 = linear_model.predict([[2022]])

# %%
predicted_price_2022
# Out:
# array([743601.61594504])

# %%
predicted_price_2022_rf = rf_model.predict([[2022]])
predicted_price_2022_rf
# Out:
# array([1.42075801])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Year', y='Price', color='blue', alpha=0.7)
plt.title('Hyundai Grand i10: Price vs Year')
plt.xlabel('Year')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# <Axes: xlabel='Year', ylabel='Price'>
