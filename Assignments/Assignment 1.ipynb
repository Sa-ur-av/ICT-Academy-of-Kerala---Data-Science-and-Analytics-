# %% [markdown]
# ## Assignment on Python for Data Science

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Reading the data set on python environment

# %%
df = pd.read_excel(r'C:\Users\Dell\Desktop\Files\Data Science\Assignments\Assignment 1\Assignment-01\iris.xls', sheet_name='Sheet1')
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 2. Displaying the columns in the dataset

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### 3. Calculating the mean of each column of the dataset

# %%
df.mean(numeric_only=True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### 4. Checking for the null values present in the dataset

# %%
null_values = df.isnull()

# %%
null_values.sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### 5. Meaningful visualizations using the dataset

# %%
column_name = {'SL': 'Sepal_Length','SW': 'Sepal_Width','PL': 'Petal_Length','PW': 'Petal_Width'}
df = df.rename(columns=column_name)

# %% [markdown]
# ##### a. Boxplot

# %%
sns.boxplot(df,palette='magma')
plt.show()

# %% [markdown]
# ##### b. Heatmap

# %%
correlation = df.corr(numeric_only=True)

# %%
sns.heatmap(correlation, annot=True, cmap='magma')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ##### c. Violinplot

# %%
sns.violinplot(x='Classification', y='Sepal_Length', data=df,palette='magma')
plt.title('Sepal length of different classifications')
plt.show()

# %% [markdown]
# ##### d. Scatterplot

# %%
sns.scatterplot(x='Sepal_Length', y='Sepal_Width', hue='Classification', data=df, palette='magma')
plt.title('Sepal Length vs Sepal Width')
plt.legend(loc=(1.02,0))
plt.show()
